# %% [markdown]
# ### Data Collection
# This is data collection script. It collects articles from the New York Times API, formats the data appropriately, and exports the data to a CSV file.
#
# In this section, data is being collected from the New York Times API. Each request returns 10 articles, so we execute 120 requests to retrieve a total of 1,200 articles.

# %%
import requests as req
import time
API_KEY='tNmaX0xIYOc2sdA0NGlDzw0i72gLNFmQ' #insert your API_KEY 
TOPIC='Technology'
articles = []
for i in range(2):
    url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+TOPIC+'&begin_date=20230919&end_date=20230919&api-key='+API_KEY+'&page='+str(i)
    print(url)
    #url='https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=tNmaX0xIYOc2sdA0NGlDzw0i72gLNFmQ'
    response = req.get(url).json()
# Extract the necessary fields from the response.
    docs = response['response']['docs']
    for doc in docs:
        filteredDoc = {}
        filteredDoc['title'] = doc['headline']['main']
        filteredDoc['abstract'] = doc['abstract']
        filteredDoc['paragraph']=doc['lead_paragraph']
        filteredDoc['url'] = doc['web_url']

        articles.append(filteredDoc)

# Done to avoid hitting the API request limit.
    time.sleep(6)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Technology&begin_date=20230919&end_date=20230919&api-key=tNmaX0xIYOc2sdA0NGlDzw0i72gLNFmQ&page=0
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Technology&begin_date=20230919&end_date=20230919&api-key=tNmaX0xIYOc2sdA0NGlDzw0i72gLNFmQ&page=1
# [{'title': 'Google Connects A.I. Chatbot Bard to YouTube, Gmail and More Facts',
#   'abstract': 'Google hopes that giving its chatbot more capabilities and improving its accuracy will give more users a reason to use it.',
#   'paragraph': 'In March, Google released an artificial intelligence chatbot called Bard. It was Google’s answer to OpenAI’s hugely popular ChatGPT.',
#   'url': 'https://www.nytimes.com/2023/09/19/technology/google-bard-ai-chatbot-youtube-gmail.html'},
#  {'title': 'Britain Passes Sweeping New Online Safety Law',
#   'abstract': 'The far-reaching bill had set off debates about balancing free speech and privacy rights against efforts to halt the spread of harmful content online.',
#   'paragraph': 'Britain passed a sweeping law on Tuesday to regulate online content, introducing age-verification requirements for pornography sites and other rules to reduce hate speech, harassment and other illicit material.',
#   'url': 'https://www.nytimes.com/2023/09/19/technology/britain-online-safety-law.html'},
#  {'title': 'Billions to Connect Everyone to High-Speed Internet Could Still Fall Short',
#   'abstract': 'President Biden has promised to provide every American access to reliable high-speed internet. But some have raised concerns about whether the funds will achieve all of the administration’s goals.',
#   'paragraph': 'Along the southeastern edge of Oklahoma, where expansive cattle ranches and empty storefronts dot the landscape, the lack of high-speed internet service has become a daily frustration for residents.',
#   'url': 'https://www.nytimes.com/2023/09/19/us/politics/high-speed-internet-biden.html'},
#  {'title': 'Max to Stream Pro Sports Starting in October',
#   'abstract': 'Media companies are racing to figure out how to merge live sporting events with their popular but still cash-bleeding streaming services.',
#   'paragraph': 'Sports continues to make its march to streaming.',
#   'url': 'https://www.nytimes.com/2023/09/19/technology/max-pro-sports-streaming.html'},
#  {'title': 'YouTube Blocks Russell Brand From Making Money Through Its Platform',
#   'abstract': 'The comedian’s channel has over six million followers, but he will be unable to draw income from advertising around his videos.',
#   'paragraph': 'YouTube suspended the comedian and actor Russell Brand on Tuesday from making money from videos posted to the social media platform, three days after British news organizations published an investigation in which several women accused Mr. Brand of sexual assault.',
#   'url': 'https://www.nytimes.com/2023/09/19/arts/russell-brand-youtube.html'},
#  {'title': 'Instacart Rises 12% on First Day of Trading, an Encouraging Sign for Tech I.P.O.s',
#   'abstract': 'Shares opened at $42 on Tuesday before declining, valuing the grocery delivery company at $11.1 billion.',
#   'paragraph': 'Initial public offerings are back, warts and all.',
#   'url': 'https://www.nytimes.com/2023/09/19/technology/instacart-ipo-stock-shares.html'},
#  {'title': 'U.A.W. Threatens Strikes at More Plants',
#   'abstract': 'The United Auto Workers union said workers would walk out of more plants on Friday if it didn’t make progress in talks with General Motors, Ford and Stellantis.',
#   'paragraph': 'The United Auto Workers said on Tuesday that the union would expand its strike against three U.S. automakers on Friday if it was unable to make substantial progress in contract talks with them.',
#   'url': 'https://www.nytimes.com/2023/09/19/business/economy/uaw-strikes-gm-ford-stellantis.html'},
#  {'title': 'Pinocchio Takes No Prisoners in a Punishing New Video Game',
#   'abstract': 'Lies of P, from a studio targeting fans of Bloodborne, Sekiro and the Dark Souls series, traces an arduous journey to end a puppet rebellion.',
#   'paragraph': 'To challenge the undisputed champion of souls-like video games, a genre acclaimed for its opaque stories, epic boss battles and punishing difficulty, a young South Korean studio turned to an insecure puppet who has a shaky relationship with the truth.',
#   'url': 'https://www.nytimes.com/2023/09/19/arts/lies-of-p-pinocchio-video-game.html'},
#  {'title': 'Strike Is a High-Stakes Gamble for Autoworkers and the Labor Movement',
#   'abstract': 'Experts on unions and the industry said the U.A.W. strike could accelerate a wave of worker actions, or stifle labor’s recent momentum.',
#   'paragraph': 'Since the start of the pandemic, labor unions have enjoyed something of a renaissance. They have made inroads into previously nonunion companies like Starbucks and Amazon, and won unusually strong contracts for hundreds of thousands of workers. Last year, public approval for unions reached its highest level since the Lyndon Johnson presidency.',
#   'url': 'https://www.nytimes.com/2023/09/19/business/economy/strike-autoworkers-labor.html'},
#  {'title': 'For People With Disabilities, Technology Needs to Do More',
#   'abstract': 'In “Against Technoableism,” Ashley Shew argues that it’s not the individuals who need “fixing,” it’s their environment.',
#   'paragraph': 'Ashley Shew was teaching a class on cyborgs when she became one.',
#   'url': 'https://www.nytimes.com/2023/09/19/books/review/against-technoableism-ashley-shew.html'}]

# %%
#check if we have 1200 articles
len(articles)
# Out:
# 9

# %%
url='https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=tNmaX0xIYOc2sdA0NGlDzw0i72gLNFmQ'
response = req.get(url).json()
print(response)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company.  All Rights Reserved.', 'num_results': 20, 'results': [{'uri': 'nyt://article/698bbb23-e064-5492-8515-bb4f9d07bb0d', 'url': 'https://www.nytimes.com/2023/09/18/us/politics/trump-calabresi-14th-amendment.html', 'id': 100000009090059, 'asset_id': 100000009090059, 'source': 'New York Times', 'published_date': '2023-09-18', 'updated': '2023-09-18 23:11:17', 'section': 'U.S.', 'subsection': 'Politics', 'nytdsection': 'u.s.', 'adx_keywords': 'Presidential Election of 2024;Fourteenth Amendment (US Constitution);United States Politics and Government;Trump, Donald J;Calabresi, Steven G;Mukasey, Michael B;Federalist Society', 'column': None, 'byline': 'By Adam Liptak', 'type': 'Article', 'title': 'An About-Face on Whether the 14th Amendment Bars Trump From Office', 'abstract': 'Steven Calabresi, a founder of the Federalist Society, recently — and forcefully — said the former president was disqualified. He has had a change of heart.', 'des_facet': ['Presidential Election of 2024', 'Fourteenth Amendment (US Constitution)', 'United States Politics and Government'], 'org_facet': ['Federalist Society'], 'per_facet': ['Trump, Donald J', 'Calabresi, Steven G', 'Mukasey, Michael B'], 'geo_facet': [], 'media': [{'type': 'image', 'subtype': 'photo', 'caption': 'A legal debate has emerged over whether the 14th Amendment bars Donald J. Trump from running for president in 2024.', 'copyright': 'Kenny Holston/The New York Times', 'approved_for_syndication': 1, 'media-metadata': [{'url': 'https://static01.nyt.com/images/2023/09/18/multimedia/18dc-bar1-hvwp/18dc-bar1-hvwp-thumbStandard.jpg', 'format': 'Standard Thumbnail', 'height': 75, 'width': 75}, {'url': 'https://static01.nyt.com/images/2023/09/18/multimedia/18dc-bar1-hvwp/18dc-bar1-hvwp-mediumThreeByTwo210.jpg', 'format': 'mediumThreeByTwo210', 'height': 140, 'width': 210}, {'url': 'https://static01.nyt.com/images/2023/09/18/multimedia/18dc-bar1-hvwp/18dc-bar1-hvwp-mediumThreeByTwo440.jpg', 'format': 'mediumThreeByTwo440', 'height': 293, 'width': 440}]}], 'eta_id': 0}, {'uri': 'nyt://article/dd5c19f8-0ad7-5d20-8f65-587ec37eb128', 'url': 'https://www.nytimes.com/2023/09/18/us/us-news-college-ranking.html', 'id': 100000009073924, 'asset_id': 100000009073924, 'source': 'New York Times', 'published_date': '2023-09-18', 'updated': '2023-09-18 23:08:48', 'section': 'U.S.', 'subsection': '', 'nytdsection': 'u.s.', 'adx_keywords': 'Colleges and Universities;Pell Grants;US News & World Report;Rutgers, The State University of New Jersey;United States', 'column': None, 'byline': 'By Alan Blinder', 'type': 'Article', 'title': 'With a New Formula, U.S. News Rankings Boost Some State Universities', 'abstract': 'Responding to critics, the publication made its biggest changes to its method in four decades. But it’s unclear whether that is enough to quiet the naysayers.', 'des_facet': ['Colleges and Universities', 'Pell Grants'], 'org_facet': ['US News & World Report', 'Rutgers, The State University of New Jersey'], 'per_facet': [], 'geo_facet': ['United States'], 'media': [{'type': 'image', 'subtype': 'photo', 'caption': 'Princeton landed on top as the best national university for the 13th consecutive year.', 'copyright': 'an Rong Xu for The New York Times', 'approved_for_syndication': 1, 'media-metadata': [{'url': 'https://static01.nyt.com/images/2023/09/18/multimedia/18nat-usnews-rankings-blhj/18nat-usnews-rankings-blhj-thumbStandard.jpg', 'format': 'Standard Thumbnail', 'height': 75, 'width': 75}, {'url': 'https://static01.nyt.com/images/2023/09/18/multimedia/18nat-usnews-rankings-blhj/18nat-usnews-rankings-blhj-mediumThreeByTwo210.jpg', 'format': 'mediumThreeByTwo210', 'height': 140, 'width': 210}, {'url': 'https://static01.nyt.com/images/2023/09/18/multimedia/18nat-usnews-rankings-blhj/18nat-usnews-rankings-blhj-mediumThreeByTwo440.jpg', 'format': 'mediumThreeByTwo440', 'height': 293, 'width': 440}]}], 'eta_id': 0}, {'uri': 'nyt://i ...

# %% [markdown]
# ### Data Export
#
# We now create a Pandas DataFrame of the data and export it to a CSV file.

# %%
import pandas as pd
df = pd.DataFrame(data=articles)
df.to_csv('TechArticles.csv')
